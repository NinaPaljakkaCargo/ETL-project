# %%
#this is my life expectancy data cleaning notebook

# %%
# Dependencies and Setup
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine

# %%
# File to Load
life_data = "lifeData.csv"

# Read Data File and store into Pandas DataFrames
life_df = pd.read_csv(life_data)
life_df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
life_clean = life_df.drop('Total expenditure',axis =1)
life_clean = life_clean.drop('percentage expenditure',axis =1)
life_clean = life_clean.drop('Income composition of resources',axis =1)

# %%
life_clean = life_clean.drop('Alcohol',axis =1)
life_clean = life_clean.drop('under-five deaths ',axis=1)
life_clean = life_clean.drop(' thinness  1-19 years',axis =1)
life_clean = life_clean.drop(' thinness 5-9 years',axis =1)

life_clean.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Hepatitis B  Measles    BMI   Polio  Diphtheria    HIV/AIDS  \
# 0             62         65.0      1154   19.1    6.0         65.0        0.1
# 1             64         62.0       492   18.6   58.0         62.0        0.1
# 2             66         64.0       430   18.1   62.0         64.0        0.1
# 3             69         67.0      2787   17.6   67.0         67.0        0.1
# 4             71         68.0      3013   17.2   68.0         68.0        0.1
#
#           GDP  Population  Schooling
# 0  584.259210  33736494.0       10.1
# ...

# %%
life_clean.to_csv('life_exp_clean.csv')

# %%
#data for developing countries, all years (2000-2015)

#df for all years
country_stats = life_clean.drop('infant deaths',axis=1)
country_stats = country_stats.drop('Hepatitis B',axis=1)
country_stats = country_stats.drop('Measles ',axis=1)
country_stats = country_stats.drop(' BMI ',axis=1)
country_stats = country_stats.drop('Polio',axis=1)
country_stats = country_stats.drop('Diphtheria ',axis=1)
country_stats = country_stats.drop(' HIV/AIDS',axis=1)

country_stats.head()

developING_00_15 = country_stats[country_stats.Status == 'Developing']

developING_00_15.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#           GDP  Population  Schooling
# 0  584.259210  33736494.0       10.1
# 1  612.696514    327582.0       10.0
# 2  631.744976  31731688.0        9.9
# 3  669.959000   3696958.0        9.8
# 4   63.537231   2978599.0        9.5

# %%
developING_00_15.to_csv('developING_00_15.csv')

# %%
#data for developed countries, all years (2000-2015)

#df for all years
country_stats_2 = life_clean.drop('infant deaths',axis=1)
country_stats_2 = country_stats_2.drop('Hepatitis B',axis=1)
country_stats_2 = country_stats_2.drop('Measles ',axis=1)
country_stats_2 = country_stats_2.drop(' BMI ',axis=1)
country_stats_2 = country_stats_2.drop('Polio',axis=1)
country_stats_2 = country_stats_2.drop('Diphtheria ',axis=1)
country_stats_2 = country_stats_2.drop(' HIV/AIDS',axis=1)

developED_00_15 = country_stats_2[country_stats_2.Status == 'Developed']

developED_00_15.head()
# Out:
#        Country  Year     Status  Life expectancy   Adult Mortality  \
# 112  Australia  2015  Developed              82.8             59.0
# 113  Australia  2014  Developed              82.7              6.0
# 114  Australia  2013  Developed              82.5             61.0
# 115  Australia  2012  Developed              82.3             61.0
# 116  Australia  2011  Developed              82.0             63.0
#
#              GDP  Population  Schooling
# 112  56554.38760  23789338.0       20.4
# 113  62214.69120   2346694.0       20.4
# 114  67792.33860  23117353.0       20.3
# 115  67677.63477  22728254.0       20.1
# 116  62245.12900    223424.0       19.8

# %%
developED_00_15.to_csv('developED_00_15.csv')

# %%
#mortality and life expectancy by country, including country status by developed(ing), GDP, schooling (2015)
#only year 2015
country_status_15 = life_clean[life_clean.Year == 2015]
#drop infant deaths, virus data, BMI
country_status_15 = country_status_15.drop('infant deaths',axis=1)
country_status_15 = country_status_15.drop('Hepatitis B',axis=1)
country_status_15 = country_status_15.drop('Measles ',axis=1)
country_status_15 = country_status_15.drop(' BMI ',axis=1)
country_status_15 = country_status_15.drop('Polio',axis=1)
country_status_15 = country_status_15.drop('Diphtheria ',axis=1)
country_status_15 = country_status_15.drop(' HIV/AIDS',axis=1)

country_status_15.head()
# Out:
#                 Country  Year      Status  Life expectancy   Adult Mortality  \
# 0           Afghanistan  2015  Developing              65.0            263.0
# 16              Albania  2015  Developing              77.8             74.0
# 32              Algeria  2015  Developing              75.6             19.0
# 48               Angola  2015  Developing              52.4            335.0
# 64  Antigua and Barbuda  2015  Developing              76.4             13.0
#
#              GDP  Population  Schooling
# 0     584.259210  33736494.0       10.1
# 16   3954.227830     28873.0       14.2
# 32   4132.762920  39871528.0       14.4
# 48   3695.793748   2785935.0       11.4
# 64  13566.954100         NaN       13.9

# %%
country_status_15.to_csv('country_status_15.csv')

# %%
#data for developing countries in 2015
developing_15 = country_status_15[country_status_15.Status == 'Developing']

developing_15.head()
# Out:
#                 Country  Year      Status  Life expectancy   Adult Mortality  \
# 0           Afghanistan  2015  Developing              65.0            263.0
# 16              Albania  2015  Developing              77.8             74.0
# 32              Algeria  2015  Developing              75.6             19.0
# 48               Angola  2015  Developing              52.4            335.0
# 64  Antigua and Barbuda  2015  Developing              76.4             13.0
#
#              GDP  Population  Schooling
# 0     584.259210  33736494.0       10.1
# 16   3954.227830     28873.0       14.2
# 32   4132.762920  39871528.0       14.4
# 48   3695.793748   2785935.0       11.4
# 64  13566.954100         NaN       13.9

# %%
developing_15.to_csv('developing_15.csv')

# %%
#developed countries in 2015
developed_15 = country_status_15[country_status_15.Status == 'Developed']

developed_15.head(12)
# Out:
#         Country  Year     Status  Life expectancy   Adult Mortality  \
# 112   Australia  2015  Developed              82.8             59.0
# 128     Austria  2015  Developed              81.5             65.0
# 240     Belgium  2015  Developed              81.1             74.0
# 384    Bulgaria  2015  Developed              74.5            137.0
# 641     Croatia  2015  Developed              78.0             95.0
# 673      Cyprus  2015  Developed              85.0             52.0
# 689     Czechia  2015  Developed              78.8             86.0
# 737     Denmark  2015  Developed              86.0             71.0
# 994     Germany  2015  Developed              81.0             68.0
# 1154    Hungary  2015  Developed              75.8            134.0
# 1170    Iceland  2015  Developed              82.7             49.0
# 1250    Ireland  2015  Developed              81.4             64.0
#
#               GDP  Population  Schooling
# ...

# %%
developed_15.to_csv('developed_15.csv')

# %%
rds_connection_string = "postgres:Finnlady3!@localhost:5432/life_exp"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['life_exp_clean',
#  'developing_all_yrs',
#  'developed_all_yrs',
#  'all_countries_2015',
#  'developing_2015',
#  'developed_2015']

# %%
#load csv converted df into database
#life expectancy data cleaned
life_clean.to_sql(name='life_exp_clean', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\.conda\envs\DataBootCamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1263                     self.dialect.do_executemany(
# -> 1264                         cursor, statement, parameters, context
#    1265                     )
#
# ~\.conda\envs\DataBootCamp\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UndefinedColumn: column "Country" of relation "life_exp_clean" does not exist
# LINE 1: INSERT INTO life_exp_clean ("Country", "Year", "Status", "Li...
#                                     ^
#
#
# ...

# %%
#load csv converted df into database
#developing countries, all years
developING_00_15.to_sql(name='developing_all_yrs', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\.conda\envs\DataBootCamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1263                     self.dialect.do_executemany(
# -> 1264                         cursor, statement, parameters, context
#    1265                     )
#
# ~\.conda\envs\DataBootCamp\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UndefinedColumn: column "Country" of relation "developing_all_yrs" does not exist
# LINE 1: INSERT INTO developing_all_yrs ("Country", "Year", "Status",...
#                                         ^
#
#
# ...

# %%
#load csv converted df into database
#developed countries, all years
developED_00_15.to_sql(name='developed_all_yrs', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\.conda\envs\DataBootCamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1263                     self.dialect.do_executemany(
# -> 1264                         cursor, statement, parameters, context
#    1265                     )
#
# ~\.conda\envs\DataBootCamp\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UndefinedColumn: column "Country" of relation "developed_all_yrs" does not exist
# LINE 1: INSERT INTO developed_all_yrs ("Country", "Year", "Status", ...
#                                        ^
#
#
# ...

# %%
#load csv converted df into database
#all countries, year 2015
country_status_15.to_sql(name='all_countries_2015', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\.conda\envs\DataBootCamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1263                     self.dialect.do_executemany(
# -> 1264                         cursor, statement, parameters, context
#    1265                     )
#
# ~\.conda\envs\DataBootCamp\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UndefinedColumn: column "Country" of relation "all_countries_2015" does not exist
# LINE 1: INSERT INTO all_countries_2015 ("Country", "Year", "Status",...
#                                         ^
#
#
# ...

# %%
#load csv converted df into database
#developing countries, year 2015
developing_15.to_sql(name='developing_2015', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\.conda\envs\DataBootCamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1263                     self.dialect.do_executemany(
# -> 1264                         cursor, statement, parameters, context
#    1265                     )
#
# ~\.conda\envs\DataBootCamp\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UndefinedColumn: column "Country" of relation "developing_2015" does not exist
# LINE 1: INSERT INTO developing_2015 ("Country", "Year", "Status", "L...
#                                      ^
#
#
# ...

# %%
#load csv converted df into database
#developed countries, year 2015
developed_15.to_sql(name='developed_2015', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\.conda\envs\DataBootCamp\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1263                     self.dialect.do_executemany(
# -> 1264                         cursor, statement, parameters, context
#    1265                     )
#
# ~\.conda\envs\DataBootCamp\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UndefinedColumn: column "Country" of relation "developed_2015" does not exist
# LINE 1: INSERT INTO developed_2015 ("Country", "Year", "Status", "Li...
#                                     ^
#
#
# ...
